# %%
# !pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-0.22.2.post1-cp37-cp37m-macosx_10_9_x86_64.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 4.1 MB/s eta 0:00:01
# Collecting joblib>=0.11
#   Downloading joblib-0.14.1-py2.py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 6.6 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=0.17.0 in ./matplotVenv/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in ./matplotVenv/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.18.3)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1315 sha256=65718082358d0e8269e862eda1f2a855ac4f74ce024f0266ec0992e4d29a91a2
#   Stored in directory: /Users/felipe/Library/Caches/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# Installing collected packages: joblib, scikit-learn, sklearn
# Successfully installed joblib-0.14.1 scikit-learn-0.22.2.post1 sklearn-0.0

# %%
from sklearn.datasets import make_blobs
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = make_blobs()

# %%
points = data[0]

# %%
x, y = points[:, 0], points[:, 1]

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
np.random.shuffle(points) # It's a random test on 'points' and I'll get the same graph

# %%
plt.scatter(points[:,0], points[:,1])

# %%
plt.scatter(x, y, c=data[1])
